# %%
import numpy as np
import matplotlib.pyplot as plt
#import datetime
#import pickle
#import time
#from scipy.interpolate import interp1d
#from matplotlib.dates import DateFormatter
#import matplotlib.dates as mdates

print('tell me this', 5)

f = np.asarray([6, 4, 3])
g = np.nanmean(f)

print(g)
# Out:
# tell me this 5
# 4.333333333333333
